# %% [markdown]
# <a href="https://colab.research.google.com/github/Elcianecorreia/akana/blob/main/Desenvolvimento2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# atividade de codigo python

# %%
#Atividade pratica 2
def classificar_habilitação():
  print ("Habilitaçao")

  try:
     quantidade_rodas = int(input("quantidade de rodas"))
     peso= float (input("peso do carro"))
     quantidade_pessoas = int (inpurt("quantas pessoas"))
  print ("\Resposta dos dados:")

     #Creio que precisamos dar a informaçao pro sistema saber qual resposta dar
  if quantidade_rodas == 2
    print ("Carteira 'A'")
  elif quantidade_rodas >=4:
   if quantidades_de_pessoas > 8:
        print ("'Carteira e'")
  elif peso>5000
        print ("'Carteira E'")
  elif 3500<= peso<= 5000
        print ("Carteira B")
# Out:
#   File "/tmp/ipython-input-2813855671.py", line 9
#     print ("\Resposta dos dados:")
#     ^
# SyntaxError: expected 'except' or 'finally' block
