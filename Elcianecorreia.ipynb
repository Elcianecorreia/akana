# %% [markdown]
# <a href="https://colab.research.google.com/github/Elcianecorreia/akana/blob/main/Elcianecorreia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Lógica de Programação

#Exercício 1

nota = 10

res1 = nota <= 10

print(f"Exercício 1: {res1}")

#Exercício 2

nota = 6

faltas = 4

res2 = (nota <= 6) and (faltas <= 3)

print(f"Exercício 2: {res2}")

#Exercício 3

convidados = 3
fumante = False

res3 = (convidados > 4) or (fumante == True)

print(f"Exercício 3: {res3}")

#Exercício 4

dia = "qua"

res4 = (dia == "sab") or (dia == "dom")

print(f"Exercício 4: {res4}")

#Exercício 5

feriado = True

res5 = not(feriado == False)

print(f"Exercício 5: {res5}")

#Exercício 6

dia = "ter"
feriado = False

res6 = (dia == "seg") or not(feriado == False)

print(f"Exercício 6: {res6}")

print("-" * 30)

 #usando os comentarios como a carol ensinou !
# Out:
# Exercício 1: True
# Exercício 2: False
# Exercício 3: False
# Exercício 4: False
# Exercício 5: True
# Exercício 6: False
# ------------------------------
